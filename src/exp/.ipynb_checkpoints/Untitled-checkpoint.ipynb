# %%
import pandas
import json

with open("../sample_domains/movies/tc_bot_movie_data/moviekb_dict.json", "r") as file:
    j = file.read()
data = json.loads(j)

# %%
tbl = []
for k,v in data.items():
    tbl.append(v)
    
pandas.DataFrame(tbl)
# Out:
#     actor actress         city                        conversationid  \
# 0     NaN     NaN       tulare  1be689ff-ab3c-4ae3-8969-b7d57098bffc
# 1     NaN     NaN       tulare  1be689ff-ab3c-4ae3-8969-b7d57098bffc
# 2     NaN     NaN       tulare  1be689ff-ab3c-4ae3-8969-b7d57098bffc
# 3     NaN     NaN       tulare  1be689ff-ab3c-4ae3-8969-b7d57098bffc
# 4     NaN     NaN       tulare  1be689ff-ab3c-4ae3-8969-b7d57098bffc
# 5     NaN     NaN     portland  3b343e7b-ccd5-48bb-9376-facf12a5b51b
# 6     NaN     NaN     portland  3b343e7b-ccd5-48bb-9376-facf12a5b51b
# 7     NaN     NaN     portland  3b343e7b-ccd5-48bb-9376-facf12a5b51b
# 8     NaN     NaN  los angeles  cc83cb76-8486-4e66-9312-fb298edad424
# 9     NaN     NaN  los angeles  cc83cb76-8486-4e66-9312-fb298edad424
# 10    NaN     NaN  los angeles  cc83cb76-8486-4e66-9312-fb298edad424
# 11    NaN     NaN  los angeles  cc83cb76-8486-4e66-9312-fb298edad424
# 12    NaN     NaN  los angeles  cc83cb76-8486-4e66-9312-fb298edad424
# 13    NaN     NaN  los angeles  cc83cb76-8486-4e66-9312-fb298edad424
# 14    NaN     NaN  los angeles  cc83cb76-8486-4e66-9312-fb298edad424
# 15    NaN     NaN  los angeles  cc83cb76-8486-4e66-9312-fb298edad424
# 16    NaN     NaN  los angeles  cc83cb76-8486-4e66-9312-fb298edad424
# 17    NaN     NaN  los angeles  cc83cb76-8486-4e66-9312-fb298edad424
# 18    NaN     NaN  los angeles  cc83cb76-8486-4e66-9312-fb298edad424
# 19    NaN     NaN  los angeles  cc83cb76-8486-4e66-9312-fb298edad424
# 20    NaN     NaN  los angeles  cc83cb76-8486-4e66-9312-fb298edad424
# 21    NaN     NaN  los angeles  cc83cb76-8486-4e66-9312-fb298edad424
# 22    NaN     NaN  los angeles  cc83cb76-8486-4e66-9312-fb298edad424
# 23    NaN     NaN  los angeles  cc83cb76-8486-4e66-9312-fb298edad424
# 24    NaN     NaN  los angeles  cc83cb76-8486-4e66-9312-fb298edad424
# 25    NaN     NaN  los angeles  cc83cb76-8486-4e66-9312-fb298edad424
# 26    NaN     NaN  los angeles  cc83cb76-8486-4e66-9312-fb298edad424
# 27    NaN     NaN  los angeles  cc83cb76-8486-4e66-9312-fb298edad424
# 28    NaN     NaN  los angeles  cc83cb76-8486-4e66-9312-fb298edad424
# 29    NaN     NaN  los angeles  cc83cb76-8486-4e66-9312-fb298edad424
# ..    ...     ...          ...                                   ...
# 364   NaN     NaN       hoover  2f3f1c57-a2e4-4eef-9845-0802cf62455e
# 365   NaN     NaN       hoover  2f3f1c57-a2e4-4eef-9845-0802cf62455e
# 366   NaN     NaN       hoover  2f3f1c57-a2e4-4eef-9845-0802cf62455e
# 367   NaN     NaN       hoover  2f3f1c57-a2e4-4eef-9845-0802cf62455e
# 368   NaN     NaN       hoover  2f3f1c57-a2e4-4eef-9845-0802cf62455e
# 369   NaN     NaN       hoover  2f3f1c57-a2e4-4eef-9845-0802cf62455e
# 370   NaN     NaN       hoover  2f3f1c57-a2e4-4eef-9845-0802cf62455e
# 371   NaN     NaN      seattle  62a0064b-4c81-4199-a2e1-647bc8a7ec6b
# 372   NaN     NaN      seattle  83adb592-fa6e-4a34-a191-b3e81cfc4572
# 373   NaN     NaN      seattle  fa29bdbc-f914-4796-a2d7-79e45b3102c0
# 374   NaN     NaN   Des Moines  f48ab6ff-27c8-4af1-b726-5d6eea33846c
# 375   NaN     NaN          NaN  829f7f20-639f-407f-a7bb-6d8a232eeecd
# 376   NaN     NaN    johnstown  29a2f6dd-086c-456c-9c43-d80b19964803
# 377   NaN     NaN    johnstown  29a2f6dd-086c-456c-9c43-d80b19964803
# 378   NaN     NaN          NaN  a17a59c8-351a-4817-8374-0359163b888f
# 379   NaN     NaN          NaN  a17a59c8-351a-4817-8374-0359163b888f
# 380   NaN     NaN     hamilton  e34f59d8-6be9-4e3a-b571-ffcc4f807e9f
# 381   NaN     NaN     hamilton  e34f59d8-6be9-4e3a-b571-ffcc4f807e9f
# 382   NaN     NaN     hamilton  e34f59d8-6be9-4e3a-b571-ffcc4f807e9f
# 383   NaN     NaN     hamilton  e34f59d8-6be9-4e3a-b571-ffcc4f807e9f
# 384   NaN     NaN     hamilton  e34f59d8-6be9-4e3a-b571-ffcc4f807e9f
# 385   NaN     NaN     hamilton  e34f59d8-6be9-4e3a-b571-ffcc4f807e9f
# 386   NaN     NaN     hamilton  e34f59d8-6be9-4e3a-b571-ffcc4f807e9f
# 387   NaN     NaN     hamilton  e34f59d8-6be9-4e3a-b571-ffcc4f807e9f
# 388   NaN     NaN     hamilton  e34f59d8-6be9-4e3a-b571-ffcc4f807e9f
# 389   NaN     NaN     hamilton  e34f59d8-6be9-4e3a-b571-ffcc4f807e9f
# 390   NaN     NaN     hamilton  e34f59d8-6be9-4e3a-b571-ffcc4f807e9f
# 391   NaN     NaN     hamilton  e34f59d8-6be9-4e3a-b571-ffcc4f807e9f
# 392   NaN     NaN     hamilton  e34f59d8-6be9-4e3a-b571-ffcc4f807e9f
# 393   NaN     NaN    las vegas  140cb755-c345-43a5-b21a-43c00b4a67d1
#
#     critic_rating      date   date_real description distanceconstraints  \
# 0             NaN  saturday  2016-03-12         NaN                 NaN
# 1             NaN  saturday  2016-03-12         NaN                 NaN
# 2             NaN  saturday  2016-03-12         NaN                 NaN
# 3             NaN  saturday  2016-03-12         NaN                 NaN
# 4             NaN  saturday  2016-03-12         NaN                 NaN
# 5             NaN  saturday  2016-03-12         NaN                 NaN
# 6             NaN       NaN         NaN         NaN                 NaN
# 7             NaN       NaN         NaN         NaN                 NaN
# 8             NaN  tomorrow  2016-03-11         NaN                 NaN
# 9             NaN  tomorrow  2016-03-11         NaN                 NaN
# 10            NaN  tomorrow  2016-03-11         NaN                 NaN
# 11            NaN  tomorrow  2016-03-11         NaN                 NaN
# 12            NaN  tomorrow  2016-03-11         NaN                 NaN
# 13            NaN  tomorrow  2016-03-11         NaN                 NaN
# 14            NaN  tomorrow  2016-03-11         NaN                 NaN
# 15            NaN  tomorrow  2016-03-11         NaN                 NaN
# 16            NaN  tomorrow  2016-03-11         NaN                 NaN
# 17            NaN  tomorrow  2016-03-11         NaN                 NaN
# 18            NaN  tomorrow  2016-03-11         NaN                 NaN
# 19            NaN  tomorrow  2016-03-11         NaN                 NaN
# 20            NaN  tomorrow  2016-03-11         NaN                 NaN
# 21            NaN  tomorrow  2016-03-11         NaN                 NaN
# 22            NaN  tomorrow  2016-03-11         NaN                 NaN
# 23            NaN  tomorrow  2016-03-11         NaN                 NaN
# 24            NaN  tomorrow  2016-03-11         NaN                 NaN
# 25            NaN  tomorrow  2016-03-11         NaN                 NaN
# 26            NaN  tomorrow  2016-03-11         NaN                 NaN
# 27            NaN  tomorrow  2016-03-11         NaN                 NaN
# 28            NaN  tomorrow  2016-03-11         NaN                 NaN
# 29            NaN  tomorrow  2016-03-11         NaN                 NaN
# ..            ...       ...         ...         ...                 ...
# 364           NaN  Saturday  2016-03-12         NaN                 NaN
# 365           NaN  Saturday  2016-03-12         NaN                 NaN
# 366           NaN  Saturday  2016-03-12         NaN                 NaN
# 367           NaN  Saturday  2016-03-12         NaN                 NaN
# 368           NaN  Saturday  2016-03-12         NaN                 NaN
# 369           NaN  Saturday  2016-03-12         NaN                 NaN
# 370           NaN  Saturday  2016-03-12         NaN                 NaN
# 371           NaN   tonight  2016-03-09         NaN                 NaN
# 372           NaN   tonight  2016-03-09         NaN                 NaN
# 373           NaN  tomorrow  2016-03-09         NaN                 NaN
# 374           NaN       NaN  2016-03-08         NaN                 NaN
# 375           NaN       NaN         NaN         NaN                 NaN
# 376           NaN  tomorrow  2016-03-10         NaN                 NaN
# 377           NaN  tomorrow  2016-03-10         NaN                 NaN
# 378           NaN       NaN  2016-03-10         NaN                 NaN
# 379           NaN       NaN  2016-03-10         NaN                 NaN
# 380           NaN  tomorrow  2016-03-10         NaN                 NaN
# 381           NaN  tomorrow  2016-03-10         NaN                 NaN
# 382           NaN  tomorrow  2016-03-10         NaN                 NaN
# 383           NaN  tomorrow  2016-03-10         NaN                 NaN
# 384           NaN  tomorrow  2016-03-10         NaN                 NaN
# 385           NaN  tomorrow  2016-03-10         NaN                 NaN
# 386           NaN  tomorrow  2016-03-10         NaN                 NaN
# 387           NaN  tomorrow  2016-03-10         NaN                 NaN
# 388           NaN  tomorrow  2016-03-10         NaN                 NaN
# 389           NaN  tomorrow  2016-03-10         NaN                 NaN
# 390           NaN  tomorrow  2016-03-10         NaN                 NaN
# 391           NaN  tomorrow  2016-03-10         NaN                 NaN
# 392           NaN  tomorrow  2016-03-10         NaN                 NaN
# 393           NaN  tomorrow  2016-03-10         NaN                 NaN
#
#       genre  ...   other price starttime starttime_real         state  \
# 0       NaN  ...     NaN   NaN   11:20am        11:20am    california
# 1       NaN  ...     NaN   NaN    2:00pm         2:00pm    california
# 2       NaN  ...     NaN   NaN    4:40pm         4:40pm    california
# 3       NaN  ...     NaN   NaN    7:20pm         7:20pm    california
# 4       NaN  ...     NaN   NaN   10:05pm        10:05pm    california
# 5       NaN  ...     NaN   NaN    9:50pm         9:50pm        oregon
# 6       NaN  ...     NaN   NaN       NaN            NaN        oregon
# 7       NaN  ...     NaN   NaN       NaN            NaN        oregon
# 8       NaN  ...     NaN   NaN   11:45am        11:45am            ca
# 9       NaN  ...     NaN   NaN   12:45pm        12:45pm            ca
# 10      NaN  ...     NaN   NaN    2:30pm         2:30pm            ca
# 11      NaN  ...     NaN   NaN    3:30pm         3:30pm            ca
# 12      NaN  ...     NaN   NaN    5:10pm         5:10pm            ca
# 13      NaN  ...     NaN   NaN    6:30pm         6:30pm            ca
# 14      NaN  ...     NaN   NaN    7:55pm         7:55pm            ca
# 15      NaN  ...     NaN   NaN    9:10pm         9:10pm            ca
# 16      NaN  ...     NaN   NaN   10:45pm        10:45pm            ca
# 17      NaN  ...     NaN   NaN   11:55pm        11:55pm            ca
# 18      NaN  ...     NaN   NaN   10:10am        10:10am            ca
# 19      NaN  ...     NaN   NaN   11:00am        11:00am            ca
# 20      NaN  ...     NaN   NaN   11:50am        11:50am            ca
# 21      NaN  ...     NaN   NaN   12:30pm        12:30pm            ca
# 22      NaN  ...     NaN   NaN    1:25pm         1:25pm            ca
# 23      NaN  ...     NaN   NaN    2:20pm         2:20pm            ca
# 24      NaN  ...     NaN   NaN    3:00pm         3:00pm            ca
# 25      NaN  ...     NaN   NaN    3:50pm         3:50pm            ca
# 26      NaN  ...     NaN   NaN    4:45pm         4:45pm            ca
# 27      NaN  ...     NaN   NaN    5:25pm         5:25pm            ca
# 28      NaN  ...     NaN   NaN    7:10pm         7:10pm            ca
# 29      NaN  ...     NaN   NaN    7:55pm         7:55pm            ca
# ..      ...  ...     ...   ...       ...            ...           ...
# 364     NaN  ...     NaN   NaN    2:00pm         2:00pm            al
# 365     NaN  ...     NaN   NaN    4:05pm         4:05pm            al
# 366     NaN  ...     NaN   NaN    4:50pm         4:50pm            al
# 367     NaN  ...     NaN   NaN    6:45pm         6:45pm            al
# 368     NaN  ...     NaN   NaN    7:45pm         7:45pm            al
# 369     NaN  ...     NaN   NaN    9:30pm         9:30pm            al
# 370     NaN  ...     NaN   NaN   10:30pm        10:30pm            al
# 371  comedy  ...     NaN   NaN   9:10 PM         9:10pm            wa
# 372  comedy  ...     NaN   NaN    8:40PM         8:40pm            wa
# 373     NaN  ...     NaN   NaN       NaN            NaN            wa
# 374     NaN  ...     NaN   NaN       NaN            NaN          iowa
# 375     NaN  ...     NaN   NaN   5:00 pm         5:00pm           NaN
# 376     NaN  ...     NaN   NaN    2:45pm         2:45pm  Pennsylvania
# 377     NaN  ...     NaN   NaN    1:15pm         1:15pm  Pennsylvania
# 378     NaN  ...     NaN   NaN      1:30         1:30pm           NaN
# 379     NaN  ...     NaN   NaN      4:00         4:00pm           NaN
# 380     NaN  ...     NaN   NaN   10:30am        10:30am            nj
# 381     NaN  ...     NaN   NaN   11:10am        11:10am            nj
# 382     NaN  ...     NaN   NaN    1:10pm         1:10pm            nj
# 383     NaN  ...     NaN   NaN    1:50pm         1:50pm            nj
# 384     NaN  ...     NaN   NaN    3:45pm         3:45pm            nj
# 385     NaN  ...     NaN   NaN    4:30pm         4:30pm            nj
# 386     NaN  ...     NaN   NaN    5:20pm         5:20pm            nj
# 387     NaN  ...     NaN   NaN    6:30pm         6:30pm            nj
# 388     NaN  ...     NaN   NaN    7:15pm         7:15pm            nj
# 389     NaN  ...     NaN   NaN    9:10pm         9:10pm            nj
# 390     NaN  ...     NaN   NaN   10:30pm        10:30pm            nj
# 391     NaN  ...     NaN   NaN   12:30pm        12:30pm            nj
# 392     NaN  ...     NaN   NaN    9:30pm         9:30pm            nj
# 393     NaN  ...     NaN   NaN      1:30         1:30pm            nv
#
#     state_real                               theater theater_chain  \
# 0           ca              regal visalia stadium 10           NaN
# 1           ca              regal visalia stadium 10           NaN
# 2           ca              regal visalia stadium 10           NaN
# 3           ca              regal visalia stadium 10           NaN
# 4           ca              regal visalia stadium 10           NaN
# 5           or           Regal Pioneer Place Stadium           NaN
# 6           or                 Regal Lloyd Center 10           NaN
# 7           or                        Bagdad Theatre           NaN
# 8           ca              regal la live stadium 14           NaN
# 9           ca              regal la live stadium 14           NaN
# 10          ca              regal la live stadium 14           NaN
# 11          ca              regal la live stadium 14           NaN
# 12          ca              regal la live stadium 14           NaN
# 13          ca              regal la live stadium 14           NaN
# 14          ca              regal la live stadium 14           NaN
# 15          ca              regal la live stadium 14           NaN
# 16          ca              regal la live stadium 14           NaN
# 17          ca              regal la live stadium 14           NaN
# 18          ca         pacific theatres at the grove           NaN
# 19          ca         pacific theatres at the grove           NaN
# 20          ca         pacific theatres at the grove           NaN
# 21          ca         pacific theatres at the grove           NaN
# 22          ca         pacific theatres at the grove           NaN
# 23          ca         pacific theatres at the grove           NaN
# 24          ca         pacific theatres at the grove           NaN
# 25          ca         pacific theatres at the grove           NaN
# 26          ca         pacific theatres at the grove           NaN
# 27          ca         pacific theatres at the grove           NaN
# 28          ca         pacific theatres at the grove           NaN
# 29          ca         pacific theatres at the grove           NaN
# ..         ...                                   ...           ...
# 364         al                  carmike patton creek           NaN
# 365         al                  carmike patton creek           NaN
# 366         al                  carmike patton creek           NaN
# 367         al                  carmike patton creek           NaN
# 368         al                  carmike patton creek           NaN
# 369         al                  carmike patton creek           NaN
# 370         al                  carmike patton creek           NaN
# 371         wa                     regal meridian 16           NaN
# 372         wa                     regal meridian 16           NaN
# 373         wa  Pacific Science Center IMAX Theaters           NaN
# 374         ia                                   NaN           NaN
# 375        NaN                 AMC Elmwood Palace 20           NaN
# 376         pa                      Richland Cinemas           NaN
# 377         pa                      Richland Cinemas           NaN
# 378        NaN                 CARMIKE LEE BRANCH 15           NaN
# 379        NaN                 CARMIKE LEE BRANCH 15           NaN
# 380         nj                     MANVILLE 12 PLEX            NaN
# 381         nj                     MANVILLE 12 PLEX            NaN
# 382         nj                     MANVILLE 12 PLEX            NaN
# 383         nj                     MANVILLE 12 PLEX            NaN
# 384         nj                     MANVILLE 12 PLEX            NaN
# 385         nj                     MANVILLE 12 PLEX            NaN
# 386         nj                     MANVILLE 12 PLEX            NaN
# 387         nj                     MANVILLE 12 PLEX            NaN
# 388         nj                     MANVILLE 12 PLEX            NaN
# 389         nj                     MANVILLE 12 PLEX            NaN
# 390         nj                     MANVILLE 12 PLEX            NaN
# 391         nj      AMC DINE-IN THEATRES BRIDGEWATER           NaN
# 392         nj      AMC DINE-IN THEATRES BRIDGEWATER           NaN
# 393         nv                    Regal Colonnade 14           NaN
#
#     video_format    zip
# 0            NaN    NaN
# 1            NaN    NaN
# 2            NaN    NaN
# 3            NaN    NaN
# 4            NaN    NaN
# 5            NaN    NaN
# 6            NaN    NaN
# 7            NaN    NaN
# 8            NaN  90015
# 9            NaN  90015
# 10           NaN  90015
# 11           NaN  90015
# 12           NaN  90015
# 13           NaN  90015
# 14           NaN  90015
# 15           NaN  90015
# 16           NaN  90015
# 17           NaN  90015
# 18           NaN  90036
# 19           NaN  90036
# 20           NaN  90036
# 21           NaN  90036
# 22           NaN  90036
# 23           NaN  90036
# 24           NaN  90036
# 25           NaN  90036
# 26           NaN  90036
# 27           NaN  90036
# 28           NaN  90036
# 29           NaN  90036
# ..           ...    ...
# 364          NaN  35244
# 365          NaN  35244
# 366          NaN  35244
# 367          NaN  35244
# 368          NaN  35244
# 369          NaN  35244
# 370          NaN  35244
# 371          NaN  98101
# 372          NaN  98101
# 373          NaN    NaN
# 374          NaN    NaN
# 375          NaN    NaN
# 376           2d    NaN
# 377           3d    NaN
# 378          NaN    NaN
# 379          NaN    NaN
# 380          NaN  08835
# 381          NaN  08835
# 382          NaN  08835
# 383          NaN  08835
# 384          NaN  08835
# 385          NaN  08835
# 386          NaN  08835
# 387          NaN  08835
# 388          NaN  08835
# 389          NaN  08835
# 390          NaN  08835
# 391          NaN  08807
# 392          NaN  08807
# 393           3d    NaN
#
# [394 rows x 22 columns]

# %%
with open("../sample_domains/movies/tc_bot_movie_data/nl_pairs.json", "r") as file:
    nl_pairs = json.loads(file.read())
    file.close()

# %%
import re
r = re.compile(r"(?:^|\s)([$])(\w+)([$])")

r.findall("$test$ $hi$")
# Out:
# [('$', 'test', '$'), ('$', 'hi', '$')]

# %%
agent_nlg = { 'domain':'movie', 'version':1.0, 'regex': "(?:^|\s)([$])(\w+)([$])",
              'dialog_acts':{}}
usersim_nlg = { 'domain':'movie', 'version':1.0, 'regex': "(?:^|\s)([$])(\w+)([$])",
                'dialog_acts':{}}

for k,v in nl_pairs["dia_acts"].items(): 
    usr = dict()
    agt = dict()
    
    # handle requests seperately 
    for i in v:
        if len(i["inform_slots"]) == 0:
            usr.update({ 'default': i["nl"]["usr"] })
            agt.update({ 'default': i["nl"]["agt"] })
        else:
            ik = ','.join(sorted(i["inform_slots"]))
            usr.update({  ik : i["nl"]["usr"] })
            agt.update({  ik : i["nl"]["agt"] })
            
        if len(i["request_slots"]) > 0:
            ik = ','.join(sorted(i["inform_slots"]))
            usr.update({  ik : i["nl"]["usr"] })
            agt.update({  ik : i["nl"]["agt"] })
    
    # Update nlg respectively w/ extracted templates        
    agent_nlg.get('dialog_acts').update({k:agt})
    usersim_nlg.get('dialog_acts').update({k:usr})

# %%
with open("../sample_domains/movies/nlg_agent_rules.json", "w") as file:
    json.dump(agent_nlg, file, indent=4)
    
with open("../sample_domains/movies/nlg_usersim_rules.json", "w") as file:
    json.dump(usersim_nlg, file, indent=4)

# %%
with open("../sample_domains/movies/tc_bot_movie_data/user_first_goals.json", "r") as file:
    first_goals = json.loads(file.read())
    file.close()

# %%
discard = [ item.pop('diaact') for item in first_goals ]

with open("../sample_domains/movies/sample_staring_goals.json", "w") as file:
    json.dump(usersim_nlg, file, indent=4)
# Out:
# [{'inform_slots': {'city': 'birmingham',
#    'date': 'today',
#    'moviename': 'zootopia',
#    'numberofpeople': '1',
#    'starttime': 'around 2pm',
#    'state': 'al',
#    'theater': 'carmike summit 16'},
#   'request_slots': {}},
#  {'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'deadpool',
#    'numberofpeople': '2',
#    'starttime': '9:00 pm',
#    'theater': 'amc pacific place 11 theater'},
#   'request_slots': {}},
#  {'inform_slots': {'city': 'birmingham',
#    'date': 'today',
#    'moviename': 'deadpool',
#    'numberofpeople': '4',
#    'starttime': 'around 6pm',
#    'state': 'al',
#    'theater': 'carmike summit 16'},
#   'request_slots': {}},
#  {'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'zootopia',
#    'numberofpeople': '2',
#    'starttime': '9:10 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'hail caesar',
#    'numberofpeople': '2',
#    'starttime': '8:45 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'inform_slots': {'city': 'portland',
#    'moviename': 'star wars',
#    'numberofpeople': '5',
#    'state': 'oregon'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'room',
#    'numberofpeople': '2',
#    'starttime': '9:30 pm',
#    'theater': 'amc pacific place 11 theater'},
#   'request_slots': {}},
#  {'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'the witch',
#    'numberofpeople': '2',
#    'starttime': '9:30 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'the witch',
#    'numberofpeople': '2',
#    'starttime': '9:30 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'triple 9',
#    'numberofpeople': '6',
#    'starttime': '7:10 pm',
#    'theater': 'amc lowes oak tree'},
#   'request_slots': {}},
#  {'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'zootopia',
#    'numberofpeople': '2',
#    'starttime': '9:10 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'inform_slots': {'city': 'birmingham',
#    'date': 'today',
#    'moviename': 'deadpool',
#    'numberofpeople': '2',
#    'starttime': '4 pm',
#    'state': 'al'},
#   'request_slots': {'theater': 'UNK'}},
#  {'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'the big short',
#    'numberofpeople': '2',
#    'starttime': '8:45 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'the big short',
#    'numberofpeople': '2',
#    'starttime': '8:45 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'zootopia',
#    'numberofpeople': '2',
#    'starttime': '9:10 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'inform_slots': {'city': 'stony brook',
#    'moviename': ' Young Messiah',
#    'numberofpeople': '1',
#    'starttime': ' Matinee',
#    'state': 'ny'},
#   'request_slots': {'date': 'UNK', 'theater': 'UNK'}},
#  {'inform_slots': {'city': 'Petaluma',
#    'moviename': 'eddie the eagle',
#    'numberofpeople': '4'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'inform_slots': {'date': 'tomorrow',
#    'moviename': 'risen',
#    'numberofpeople': '3',
#    'theater': 'regency commerce 14'},
#   'request_slots': {'starttime': 'UNK'}},
#  {'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'zoolander 2',
#    'numberofpeople': '2',
#    'starttime': '9:25 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'deadpool',
#    'numberofpeople': '2',
#    'starttime': '9:00 pm',
#    'theater': 'amc pacific place 11 theater'},
#   'request_slots': {}},
#  {'inform_slots': {'date': 'saturday',
#    'moviename': 'zootopia',
#    'numberofpeople': '1',
#    'starttime': 'around 2pm'},
#   'request_slots': {'theater': 'UNK'}},
#  {'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'the witch',
#    'numberofpeople': '2',
#    'starttime': '9:30 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'inform_slots': {'moviename': 'zootopia', 'numberofpeople': '4'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'inform_slots': {'moviename': 'Avengers', 'numberofpeople': '4'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'inform_slots': {'distanceconstraints': 'close to 95833',
#    'moviename': 'zoology',
#    'numberofpeople': '3'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'race',
#    'numberofpeople': '2',
#    'starttime': '4:50 pm',
#    'theater': 'amc lowes oak tree 6'},
#   'request_slots': {}},
#  {'inform_slots': {'moviename': 'deadpool', 'numberofpeople': '3'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'hail caesar',
#    'numberofpeople': '2',
#    'starttime': '7:15 pm',
#    'theater': 'amc lowes oak tree 6'},
#   'request_slots': {}},
#  {'inform_slots': {'city': 'birmingham',
#    'date': 'today',
#    'moviename': 'zootopia',
#    'numberofpeople': '2',
#    'starttime': 'around 4pm',
#    'state': 'al'},
#   'request_slots': {'theater': 'UNK'}},
#  {'inform_slots': {'date': 'tomorrow',
#    'moviename': 'zootopia',
#    'numberofpeople': '5',
#    'starttime': 'night'},
#   'request_slots': {'theater': 'UNK'}},
#  {'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'zoolander 2',
#    'numberofpeople': '2',
#    'starttime': '9:25 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'inform_slots': {'date': 'tonight',
#    'moviename': 'zootopia',
#    'numberofpeople': '1'},
#   'request_slots': {'starttime': 'UNK', 'theater': 'UNK'}},
#  {'inform_slots': {'city': 'birmingham',
#    'date': 'saturday',
#    'moviename': 'deadpool',
#    'numberofpeople': '3',
#    'starttime': '2pm',
#    'state': 'al',
#    'theater': 'carmike summit 16'},
#   'request_slots': {}},
#  {'inform_slots': {'city': 'sacramento',
#    'date': 'tomorrow',
#    'moviename': 'gods of egypt',
#    'numberofpeople': '4',
#    'theater': 'regal theater'},
#   'request_slots': {'starttime': 'UNK'}},
#  {'inform_slots': {'date': 'tomorrow',
#    'moviename': '10 cloverfield lane',
#    'numberofpeople': '3'},
#   'request_slots': {'starttime': 'UNK', 'theater': 'UNK'}},
#  {'inform_slots': {'moviename': 'zootopia', 'numberofpeople': '2'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'zoolander 2',
#    'numberofpeople': '2',
#    'starttime': '9:25 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'inform_slots': {'date': 'tomorrow',
#    'moviename': 'risen',
#    'numberofpeople': '2',
#    'theater': 'regency commerce 14'},
#   'request_slots': {'starttime': 'UNK'}},
#  {'inform_slots': {'date': 'this friday',
#    'moviename': 'star wars',
#    'numberofpeople': '4'},
#   'request_slots': {'starttime': 'UNK', 'theater': 'UNK'}},
#  {'inform_slots': {'city': 'portland',
#    'moviename': 'zootopia',
#    'numberofpeople': '3',
#    'state': 'oregon'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'inform_slots': {'date': 'tonight',
#    'moviename': 'zootopia',
#    'numberofpeople': '5'},
#   'request_slots': {'starttime': 'UNK', 'theater': 'UNK'}},
#  {'inform_slots': {'city': 'portland',
#    'moviename': 'star wars',
#    'numberofpeople': '5',
#    'state': 'oregon'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'zootopia',
#    'numberofpeople': '2',
#    'starttime': '9:10 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'inform_slots': {'date': 'tonight',
#    'moviename': 'zootopia',
#    'numberofpeople': '1'},
#   'request_slots': {'starttime': 'UNK', 'theater': 'UNK'}},
#  {'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'hail caesar',
#    'numberofpeople': '2',
#    'starttime': '8:45 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'inform_slots': {'distanceconstraints': 'near me',
#    'moviename': 'kung fu panda 3',
#    'numberofpeople': '4'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'hail caesar',
#    'numberofpeople': '2',
#    'starttime': '8:45 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'inform_slots': {'moviename': 'london has fallen',
#    'numberofpeople': 'two',
#    'zip': '90602'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'zootopia',
#    'numberofpeople': '2',
#    'starttime': '9:10 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow night',
#    'moviename': 'zootopia',
#    'numberofpeople': 'one'},
#   'request_slots': {'starttime': 'UNK', 'theater': 'UNK'}},
#  {'inform_slots': {'moviename': 'first', 'numberofpeople': '2'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'inform_slots': {'date': 'saturday',
#    'moviename': 'zootopia',
#    'numberofpeople': '4',
#    'starttime': 'around 2pm'},
#   'request_slots': {'theater': 'UNK'}},
#  {'inform_slots': {'date': 'tonight',
#    'moviename': 'zootopia',
#    'numberofpeople': '3'},
#   'request_slots': {'starttime': 'UNK', 'theater': 'UNK'}},
#  {'inform_slots': {'moviename': 'whiskey tango foxtrot',
#    'numberofpeople': '3'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'inform_slots': {'date': 'tomorrow night',
#    'moviename': 'zootopia',
#    'numberofpeople': '5'},
#   'request_slots': {'starttime': 'UNK', 'theater': 'UNK'}},
#  {'inform_slots': {'distanceconstraints': 'near me',
#    'moviename': 'kung fu panda 3',
#    'numberofpeople': '1'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'inform_slots': {'moviename': 'london has fallen', 'numberofpeople': '5'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'inform_slots': {'city': 'portland',
#    'moviename': 'whiskey tango foxtrot',
#    'numberofpeople': '4',
#    'state': 'oregon'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'inform_slots': {'moviename': 'deadpool', 'numberofpeople': '5'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'risen',
#    'numberofpeople': '2',
#    'starttime': '4:25 pm',
#    'theater': 'amc lowes oak tree 6'},
#   'request_slots': {}},
#  {'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'room',
#    'numberofpeople': '2',
#    'starttime': '9:30 pm',
#    'theater': 'pacific place 11 theater',
#    'theater_chain': 'amc'},
#   'request_slots': {}},
#  {'inform_slots': {'city': 'seattle',
#    'moviename': 'deadpool',
#    'numberofpeople': '2'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'inform_slots': {'city': 'los angeles',
#    'date': 'tomorrow',
#    'moviename': 'deadpool',
#    'numberofpeople': '4',
#    'starttime': '8pm'},
#   'request_slots': {'theater': 'UNK'}},
#  {'inform_slots': {'date': 'this weekend',
#    'moviename': 'batman moviename',
#    'numberofpeople': '1'},
#   'request_slots': {'starttime': 'UNK', 'theater': 'UNK'}},
#  {'inform_slots': {'distanceconstraints': 'near me',
#    'moviename': 'zootopia',
#    'numberofpeople': '5'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'inform_slots': {'city': 'detroit',
#    'date': 'tomorrow',
#    'moviename': 'deadpool',
#    'numberofpeople': '3',
#    'starttime': '7pm'},
#   'request_slots': {'theater': 'UNK'}},
#  {'inform_slots': {'city': 'regency',
#    'date': 'tomorrow',
#    'moviename': 'creed',
#    'numberofpeople': 'four',
#    'starttime': 'around noon'},
#   'request_slots': {'theater': 'UNK'}},
#  {'inform_slots': {'city': 'los angeles',
#    'date': 'tomorrow',
#    'moviename': 'zootopia',
#    'numberofpeople': '5',
#    'starttime': '8pm'},
#   'request_slots': {'theater': 'UNK'}},
#  {'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'risen',
#    'numberofpeople': '2',
#    'starttime': '4:25 pm',
#    'theater': 'amc lowes oak tree 6'},
#   'request_slots': {}},
#  {'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'room',
#    'numberofpeople': '2',
#    'starttime': '9:30 pm',
#    'theater': 'amc pacific place 11 theater'},
#   'request_slots': {}},
#  {'inform_slots': {'city': 'birmingham',
#    'date': 'today',
#    'moviename': 'london had fallen',
#    'numberofpeople': '2',
#    'starttime': 'around 2pm',
#    'state': 'al',
#    'theater': 'carmike summit 16'},
#   'request_slots': {}},
#  {'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'room',
#    'numberofpeople': '2',
#    'starttime': '4:50 pm',
#    'theater': 'amc lowes oak tree 6'},
#   'request_slots': {}},
#  {'inform_slots': {'city': 'philadelphia',
#    'date': 'tomorrow',
#    'moviename': 'deadpool',
#    'numberofpeople': '3',
#    'zip': '19101'},
#   'request_slots': {'starttime': 'UNK', 'theater': 'UNK'}},
#  {'inform_slots': {'city': 'birmingham',
#    'date': 'tomorrow',
#    'moviename': 'deadpool',
#    'numberofpeople': '2',
#    'starttime': 'around 5pm',
#    'state': 'al',
#    'theater': 'carmike summit 16'},
#   'request_slots': {}},
#  {'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'The big short',
#    'numberofpeople': '2',
#    'starttime': '8:45 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'inform_slots': {'moviename': 'zootopia',
#    'numberofpeople': '4',
#    'starttime': 'matinee'},
#   'request_slots': {'date': 'UNK', 'theater': 'UNK'}},
#  {'inform_slots': {'city': 'la',
#    'date': 'tomorrow',
#    'distanceconstraints': 'downtown',
#    'moviename': 'creed',
#    'numberofpeople': '2',
#    'starttime': '7pm',
#    'video_format': '3d'},
#   'request_slots': {'theater': 'UNK'}},
#  {'inform_slots': {'city': 'birmingham',
#    'moviename': 'zootopia',
#    'numberofpeople': '2',
#    'state': 'al'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'spotlight',
#    'numberofpeople': '2',
#    'starttime': '9:00 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'inform_slots': {'moviename': 'avengers', 'numberofpeople': '5'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'spotlight',
#    'numberofpeople': '2',
#    'starttime': '9:00 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'hail caesar',
#    'numberofpeople': '2',
#    'starttime': '8:45 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'inform_slots': {'city': 'birmingham',
#    'date': 'today',
#    'moviename': 'zootopia',
#    'numberofpeople': '2',
#    'starttime': '2pm',
#    'state': 'al',
#    'theater': 'carmike 16'},
#   'request_slots': {}},
#  {'inform_slots': {'city': 'du quoin',
#    'moviename': 'star wars',
#    'numberofpeople': '2',
#    'state': 'illinois'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'hail caesar',
#    'numberofpeople': '2',
#    'starttime': '8:45 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'inform_slots': {'city': 'portland',
#    'moviename': 'star wars',
#    'numberofpeople': '2',
#    'state': 'oregon'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'inform_slots': {'city': 'los angeles',
#    'moviename': 'deadpool',
#    'numberofpeople': '1'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'inform_slots': {'city': 'regency academy 6 theater',
#    'date': 'tomorrow',
#    'moviename': 'creed',
#    'numberofpeople': 'four',
#    'starttime': 'around noon'},
#   'request_slots': {'theater': 'UNK'}},
#  {'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'spotlight',
#    'numberofpeople': '2',
#    'starttime': '9:00 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'inform_slots': {'date': 'tomorrow night',
#    'moviename': 'deadpool',
#    'numberofpeople': '1'},
#   'request_slots': {'starttime': 'UNK', 'theater': 'UNK'}},
#  {'inform_slots': {'city': 'portland',
#    'moviename': 'star wars',
#    'numberofpeople': '4',
#    'state': 'oregon'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'inform_slots': {'moviename': 'star wars',
#    'numberofpeople': '2',
#    'theater': 'shelby township'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK'}},
#  {'inform_slots': {'city': 'philadelphia',
#    'date': 'tomorrow',
#    'moviename': 'deadpool',
#    'numberofpeople': '4',
#    'zip': '19101'},
#   'request_slots': {'starttime': 'UNK', 'theater': 'UNK'}},
#  {'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'zootopia',
#    'numberofpeople': '2',
#    'starttime': '9:10 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'deadpool',
#    'numberofpeople': '2',
#    'starttime': '9:00 pm',
#    'theater': 'amc pacific place 11 theater'},
#   'request_slots': {}},
#  {'inform_slots': {'city': 'knoxville',
#    'date': 'tomorrow',
#    'distanceconstraints': 'downtown',
#    'moviename': 'the witch',
#    'numberofpeople': '2',
#    'starttime': 'evening around 7',
#    'state': 'tn',
#    'video_format': '3d'},
#   'request_slots': {'theater': 'UNK'}},
#  {'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'race',
#    'numberofpeople': '2',
#    'starttime': '10:00 pm',
#    'theater': 'amc pacific place 11 theater'},
#   'request_slots': {}},
#  {'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'zootopia',
#    'numberofpeople': '2',
#    'starttime': '9:10 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'inform_slots': {'city': 'birmingham',
#    'date': 'sunday',
#    'moviename': 'deadpool',
#    'numberofpeople': '2',
#    'starttime': 'around 2pm',
#    'state': 'al',
#    'theater': 'carmike summit 16'},
#   'request_slots': {}},
#  {'inform_slots': {'moviename': 'brothers grimsby', 'numberofpeople': '4'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'big short',
#    'numberofpeople': '2',
#    'starttime': '8:45 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'inform_slots': {'moviename': 'zootopia', 'numberofpeople': '5'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'the witch',
#    'numberofpeople': '2',
#    'starttime': '9:30 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'zootopia',
#    'numberofpeople': '2',
#    'starttime': '9:10 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'inform_slots': {'moviename': '10 cloverfield lane',
#    'numberofpeople': '3',
#    'theater': 'beaver creek stadium 12'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK'}},
#  {'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'spotlight',
#    'numberofpeople': '2',
#    'starttime': '9:00 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'race',
#    'numberofpeople': '2',
#    'starttime': '4:50 pm',
#    'theater': 'amc lowes oak tree 6'},
#   'request_slots': {}},
#  {'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'race',
#    'numberofpeople': '2',
#    'starttime': '10:00 pm',
#    'theater': 'amc pacific place 11 theater'},
#   'request_slots': {}},
#  {'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'the witch',
#    'numberofpeople': '2',
#    'starttime': '9:30 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'the witch',
#    'numberofpeople': '2',
#    'starttime': '9:30 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'inform_slots': {'city': 'birmingham',
#    'date': 'tomorrow',
#    'moviename': 'deadpool',
#    'numberofpeople': '1',
#    'starttime': '2pm',
#    'state': 'al',
#    'theater': 'carmike summit 16'},
#   'request_slots': {}},
#  {'inform_slots': {'city': 'seattle',
#    'moviename': 'deadpool',
#    'numberofpeople': '2'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'inform_slots': {'city': 'birmingham',
#    'date': 'thursday',
#    'moviename': 'deadpool',
#    'numberofpeople': '2',
#    'starttime': 'around 2pm',
#    'state': 'al',
#    'theater': 'carmike summit 16'},
#   'request_slots': {}},
#  {'inform_slots': {'moviename': 'eddie the eagle',
#    'numberofpeople': '4',
#    'zip': '94952'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'inform_slots': {'moviename': 'london has fallen',
#    'numberofpeople': 'two',
#    'zip': '90602'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'inform_slots': {'moviename': 'zootopia',
#    'numberofpeople': '4',
#    'state': 'california'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'zoolander 2',
#    'numberofpeople': '2',
#    'starttime': '9:25 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'inform_slots': {'city': 'las vegas',
#    'moviename': 'the other side of the door',
#    'numberofpeople': 'two',
#    'theater': 'southpoint casino'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK'}},
#  {'inform_slots': {'city': 'du Quoin',
#    'moviename': 'star wars',
#    'numberofpeople': '2',
#    'state': 'illinois'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'inform_slots': {'moviename': 'gods egypt', 'numberofpeople': '3'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'hail caesar',
#    'numberofpeople': '2',
#    'starttime': '8:45 pm',
#    'theater': 'regal meridian 16 theater'},
#   'request_slots': {}},
#  {'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'zootopia',
#    'numberofpeople': 'one',
#    'starttime': 'night'},
#   'request_slots': {'theater': 'UNK'}},
#  {'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'race',
#    'numberofpeople': '2',
#    'starttime': '10:00 pm',
#    'theater': 'amc pacific place 11 theater'},
#   'request_slots': {}},
#  {'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'race',
#    'numberofpeople': '2',
#    'starttime': '10:00 pm',
#    'theater': 'amc pacific place 11 theater'},
#   'request_slots': {}},
#  {'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'hail caesar',
#    'numberofpeople': '2',
#    'starttime': '7:15 pm',
#    'theater': 'amc lowes oak tree 6'},
#   'request_slots': {}},
#  {'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'triple 9',
#    'numberofpeople': '6',
#    'starttime': '7:10 pm',
#    'theater': 'amc lowes oak tree'},
#   'request_slots': {}},
#  {'inform_slots': {'moviename': 'zootopia', 'numberofpeople': 'two'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'deadpool',
#    'numberofpeople': '2',
#    'starttime': '9:00 pm',
#    'theater': 'amc pacific place 11 theater'},
#   'request_slots': {}}]
